# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## PART A

# %%
df = pd.read_csv("DataSets/employee_performance_dataset.csv")
df.head()
# Out:
#   Employee_ID    Name Department  Age  Gender  Years_at_Company  \
# 0       E1000    Seth      Sales   50    Male                11
# 1       E1001   Maria         IT   45    Male                 3
# 2       E1002    Mary         HR   42    Male                 1
# 3       E1003    Kyle      Sales   49    Male                12
# 4       E1004  Sandra  Marketing   28  Female                 5
#
#    Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 0              12                   5                   1     74.679836
# 1              10                   5                   1     91.659963
# 2              16                  10                   5     70.211989
# 3              20                   3                   3     85.427033
# 4              13                   7                   1     98.466566
#
#    Customer_Feedback  Salary(LPA)  Performance_Score
# 0                  8         8.67                7.3
# ...

# %%
df.isna().sum()
# Out:
# Employee_ID           0
# Name                  0
# Department            0
# Age                   0
# Gender                0
# Years_at_Company      0
# Goals_Achieved        0
# Projects_Completed    0
# Trainings_Attended    0
# Attendance_%          0
# Customer_Feedback     0
# Salary(LPA)           0
# Performance_Score     0
# dtype: int64

# %%
df["age group"] = [22-30,31-40,41-50]

# %% [markdown]
# ## PART B

# %%
df.groupby("Department")["Performance_Score"].mean()
df
# Out:
#     Employee_ID      Name Department  Age  Gender  Years_at_Company  \
# 0         E1000      Seth      Sales   50    Male                11
# 1         E1001     Maria         IT   45    Male                 3
# 2         E1002      Mary         HR   42    Male                 1
# 3         E1003      Kyle      Sales   49    Male                12
# 4         E1004    Sandra  Marketing   28  Female                 5
# ..          ...       ...        ...  ...     ...               ...
# 495       E1495     James         IT   57  Female                 3
# 496       E1496     Jesse         IT   27    Male                 6
# 497       E1497      Sean    Finance   42  Female                 9
# 498       E1498  Nicholas  Marketing   49    Male                 1
# 499       E1499    Darren      Sales   44  Female                 4
#
#      Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 0                12                   5                   1     74.679836
# ...

# %%
df.sort_values(by = "Performance_Score",ascending = False).head(10)
# Out:
#     Employee_ID      Name Department  Age  Gender  Years_at_Company  \
# 302       E1302     Carol      Sales   23    Male                 9
# 166       E1166      John         HR   39  Female                 1
# 245       E1245  Brittany  Marketing   32  Female                 7
# 252       E1252      Lisa         HR   49  Female                 7
# 467       E1467   Patrick      Sales   57  Female                 7
# 154       E1154     Kelly  Marketing   55  Female                 7
# 342       E1342     Scott    Finance   32  Female                 2
# 81        E1081    Martin         IT   22  Female                 5
# 202       E1202     Sarah         IT   52  Female                 6
# 28        E1028      Luke      Sales   37    Male                10
#
#      Goals_Achieved  Projects_Completed  Trainings_Attended  Attendance_%  \
# 302              20                   9                   3     85.724775
# ...

# %%
df["Salary(LPA)"].mean()
# Out:
# np.float64(11.563600000000001)

# %%
df.groupby("Department")["Salary(LPA)"].mean()
# Out:
# Department
# Finance      11.619423
# HR           10.774149
# IT           12.030306
# Marketing    11.666875
# Sales        11.684239
# Name: Salary(LPA), dtype: float64

# %%
df.groupby("Gender")["Performance_Score"].mean()
# Out:
# Gender
# Female    7.528629
# Male      7.542460
# Name: Performance_Score, dtype: float64

# %%
cor1 = df[["Attendance_%","Customer_Feedback","Trainings_Attended","Salary(LPA)","Performance_Score"]].corr().round(2)
cor1
# Out:
#                     Attendance_%  Customer_Feedback  Trainings_Attended  \
# Attendance_%                1.00               0.03                0.08
# Customer_Feedback           0.03               1.00               -0.05
# Trainings_Attended          0.08              -0.05                1.00
# Salary(LPA)                -0.03               0.03                0.00
# Performance_Score          -0.02               0.13                0.17
#
#                     Salary(LPA)  Performance_Score
# Attendance_%              -0.03              -0.02
# Customer_Feedback          0.03               0.13
# Trainings_Attended         0.00               0.17
# Salary(LPA)                1.00              -0.00
# Performance_Score         -0.00               1.00

# %% [markdown]
# ## PART C

# %%
avg = df.groupby("Department")["Performance_Score"].mean()
avg
# Out:
# Department
# Finance      7.658654
# HR           7.073404
# IT           7.702041
# Marketing    7.535714
# Sales        7.691304
# Name: Performance_Score, dtype: float64

# %%
sns.barplot(x = "Department",y = "Performance_Score"   ,data = df)
# Out:
# <Axes: xlabel='Department', ylabel='Performance_Score'>

# %%
sns.boxplot(x = "Salary(LPA)",y = "Department"   ,data = df)
# Out:
# <Axes: xlabel='Salary(LPA)', ylabel='Department'>

# %%
sns.histplot(x = "Age",data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.heatmap(cor1,annot = True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x = "Salary(LPA)",y  = "Performance_Score", data = df)
# Out:
# <Axes: xlabel='Salary(LPA)', ylabel='Performance_Score'>
