# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("fitness_data.xlsx")
data.head()
# Out:
#      name  steps_taken  calories_burned  sleep_duration(hours)  \
# 0  Akshay        10500             4500                    7.5
# 1   Priya         9800             4200                    7.2
# 2     Raj        11500             4800                    7.0
# 3   Emily        12000             5000                    7.8
# 4   Rohit         8900             4000                    7.0
#
#    water_intake(ounces)
# 0                    80
# 1                    75
# 2                    90
# 3                    85
# 4                    70

# %%
data.isna().sum()
# Out:
# name                     0
# steps_taken              0
# calories_burned          0
# sleep_duration(hours)    0
# water_intake(ounces)     0
# dtype: int64

# %%
sns.histplot(x = "sold_qty",data = data,kde = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.histplot(x = "sold_qty",data = data,kde = True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
#    1384     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
