# %%
import pandas as pd

# %%
data = pd.read_csv("shoe_sales.csv")

# %%
data.head()
# Out:
#        date   brand  sold_qty
# 0  9/1/2023    Nike      24.0
# 1  9/1/2023  Adidas      14.0
# 2  9/2/2023    Nike      21.0
# 3  9/2/2023  Adidas      12.0
# 4  9/3/2023    Nike      18.0

# %%
data.shape
# Out:
# (60, 3)

# %%
data["brand"].unique()
# Out:
# array(['Nike', 'Adidas'], dtype=object)

# %%
data["brand"].value_counts()
# Out:
# brand
# Nike      30
# Adidas    30
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    2
# dtype: int64

# %%
avg = data[data["brand"] == "Nike"]["sold_qty"].mean()

# %%
avg
# Out:
# np.float64(19.642857142857142)

# %%
data['sold_qty'] =data["sold_qty"].fillna(avg)

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(x = "sold_qty",data = data,kde = True)
# Out:
# <Axes: xlabel='sold_qty', ylabel='Count'>
